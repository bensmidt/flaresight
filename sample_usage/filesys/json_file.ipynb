# %% [markdown]
# ### Setup

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys, os

# %%
ROOT_PATH = os.path.abspath(os.path.join("..", ".."))
SRC_PATH = os.path.join(ROOT_PATH, "src")
TEST_PATH = os.path.join(ROOT_PATH, "test")
sys.path.insert(0, TEST_PATH)
sys.path.insert(0, SRC_PATH)
print(sys.path)
# Out:
# ['/Users/bensmidt/Documents/cai/backend/src', '/Users/bensmidt/Documents/cai/backend/test', '/Users/bensmidt/Documents/cai/backend/src', '/Users/bensmidt/Documents/cai/backend/test', '/Users/bensmidt/Documents/cai/backend/sample_usage/filesys', '/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python311.zip', '/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11', '/opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/lib-dynload', '', '/Users/bensmidt/Documents/cai/backend/env/lib/python3.11/site-packages', '/Users/bensmidt/Documents/cai/backend/src']

# %%
from filesys.json_file import JsonFile
from filesys.fs_manager import FileSystemManager
from test_files import TestFiles

# %%
fs_manager = FileSystemManager()
test_files = TestFiles()

# %% [markdown]
# ## Paths

# %%
INVALID_JSON_PATH = test_files.get_media_file_paths()[0]

VALID_JSON_PATH = test_files.get_json_file_paths()[6]

# %% [markdown]
# ## Sandbox

# %%
print(JsonFile(VALID_JSON_PATH).get_path())
# Out:
# /Users/bensmidt/Documents/cai/backend/test_files/transcription/10k_to_anyone.json

# %% [markdown]
# ## check_exists()

# %%
json_file = JsonFile(VALID_JSON_PATH)
print("Valid path:", json_file.check_exists())

json_file = JsonFile(INVALID_JSON_PATH)
print("Invalid path:", json_file.check_exists())
# Out:
# Valid path: None
# Invalid path: '/Users/bensmidt/Documents/cai/backend/test_files/media/image/jpeg/test_image.jpeg' is a valid File but is not a valid JsonFile because it has file extension 'jpeg' instead of 'json'.

# %% [markdown]
# ## read

# %%
json_file = JsonFile(VALID_JSON_PATH)
transcript_dict = json_file.read()
for key in transcript_dict.keys():
    print(key, ":", transcript_dict[key])
# Out:
# sourceSoftware : whisperx
# timeSpawned : 2023-05-02 19:10:22.252692
# language : en
# numSpeakers : None
# ...

# %% [markdown]
# ## write

# %%
json_file = JsonFile(os.path.join(ROOT_PATH, "test_files/transcription/deleteme.json"))
new_json_info = {"jaja": "hehe", "arglebargle": 34}
json_file.write(new_json_info)

# %% [markdown]
# ## check_exists()

# %%
file = JsonFile(VALID_JSON_PATH)
print("Valid path:", file.check_exists())

file = JsonFile(INVALID_JSON_PATH)
print("Invalid path:", file.check_exists())
# Out:
# Valid path: None
# Invalid path: '/Users/bensmidt/Documents/cai/backend/test_files/media/image/jpeg/test_image.jpeg' is a valid File but is not a valid JsonFile because it has file extension 'jpeg' instead of 'json'.
